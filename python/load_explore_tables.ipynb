# %% [markdown]
# <a href="https://colab.research.google.com/github/ijecampos/HIGI/blob/main/python/load_explore_tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **En este cuaderno se muestran algunos ejemplos de como descargar archivos con tablas directamente desde el cuaderno. Así como la manipuclación con la libreria pandas**

# %%
url = 'https://www.indexmundi.com/map/?t=0&v=25&r=xx&1=en'
html = requests.get(url).content
Birth_rate = pd.read_html(html)
Birth_rate=Birth_rate[1]

# %%
Birth_rate.head()
# Out:
#   Country  Birth rate (births/1,000 population)  Year
# 0   Niger                                    48  2020
# 1  Angola                                    43  2020
# 2  Uganda                                    42  2020
# 3    Mali                                    42  2020
# 4   Benin                                    42  2020

# %%
Birth_rate.keys()
# Out:
# Index(['Country', 'Birth rate (births/1,000 population)', 'Year'], dtype='object')

# %%
Birth_rate.describe()
# Out:
#        Birth rate (births/1,000 population)         Year
# count                            198.000000   198.000000
# mean                              18.919192  2019.959596
# std                                9.592379     0.568535
# min                                6.000000  2012.000000
# 25%                               11.000000  2020.000000
# 50%                               16.000000  2020.000000
# 75%                               23.750000  2020.000000
# max                               48.000000  2020.000000

# %%
Birth_rate[Birth_rate['Birth rate (births/1,000 population)']>19]
# Out:
#        Country  Birth rate (births/1,000 population)  Year
# 0        Niger                                    48  2020
# 1       Angola                                    43  2020
# 2       Uganda                                    42  2020
# 3         Mali                                    42  2020
# 4        Benin                                    42  2020
# ..         ...                                   ...   ...
# 68     Bolivia                                    21  2020
# 69  Kyrgyzstan                                    21  2020
# 70    Kiribati                                    20  2020
# 71     Algeria                                    20  2020
# 72       Samoa                                    20  2020
#
# [73 rows x 3 columns]

# %%
from urllib import request

# %%
url = 'https://smn.conagua.gob.mx/tools/RESOURCES/com_archivo_datos_resumenes/202201010000Lluv.csv'
request.urlretrieve(url, "2022101010000Lluv.csv")
# Out:
# ('2022101010000Lluv.csv', <http.client.HTTPMessage at 0x7f378b62d890>)

# %%
data_2021=pd.read_csv("/content/202101010000Lluv.csv", encoding = 'ISO-8859-1')
data_2022=pd.read_csv("/content/2022101010000Lluv.csv", encoding = 'ISO-8859-1')

# %%
data_2022[data_2022['EDO']=='AGS']
# Out:
#            LON        LAT  EDO       CLAVE  \
# 0  -102.309722  21.895000  AGS       AGSAG
# 1  -102.585833  22.177222  AGS       ALMAG
# 2  -102.184167  21.738611  AGS       BRTAG
# 3  -102.712222  21.849167  AGS    CALVILLO
# 4  -102.676944  21.997500  AGS       CDRAG
# 5  -102.197222  22.007222  AGS       CHOAG
# 6  -102.189167  21.826667  AGS       CLVAG
# 7  -101.992222  21.897778  AGS       CNSAG
# 8  -102.296667  22.362778  AGS       CSOAG
# 9  -102.356944  22.121667  AGS       JCQAG
# 10 -102.788333  21.807500  AGS       MNLAG
# 11 -102.371667  21.780000  AGS       NGRAG
# 12 -102.001944  22.020556  AGS       NVLAG
# 13 -102.290556  21.850833  AGS       OBSAG
# 14 -102.465000  22.189167  AGS     P50ANIV
# 15 -101.966667  21.916667  AGS       PALAG
# 16 -102.279167  22.147222  AGS       PBLAG
# 17 -102.417222  22.141111  AGS       PECAG
# 18 -102.135000  22.202778  AGS       PTOAG
# 19 -102.437500  22.235000  AGS       PTRAG
# 20 -102.608333  22.269444  AGS  SIERRAFRIA
# 21 -102.108889  21.885000  AGS       SNVAG
# 22 -102.127778  21.807778  AGS       TNJAG
# 23 -102.067500  22.097778  AGS       VJZAG
#
#                                   ESTACION  ene-22
# 0                     Aguascalientes, Ags.    1.50
# 1                           Alamitos, Ags.    5.50
# 2                        San Bartolo, Ags.    0.00
# 3                      Calvillo, Ags. SMN*    1.75
# 4                        La Codorniz, Ags.    0.00
# 5                       Cañada Honda, Ags.    0.01
# 6                           Calvillo, Ags.    1.70
# 7                          Los Conos, Ags.    0.10
# 8                              Cosío, Ags.    0.01
# 9                            Jocoque, Ags.    0.00
# 10                        Media Luna, Ags.    2.30
# 11                        El Niágara, Ags.    1.40
# 12                        El Novillo, Ags.    0.20
# 13    Observatorio de Aguascalientes, Ags.    2.40
# 14  Presa Cincuenta Aniversario, Ags. SMN*    2.20
# 15                         Palo Alto, Ags.    0.00
# 16                          Pabellón, Ags.    0.10
# 17             Plutarco Elías Calles, Ags.    1.50
# 18           Puerto de la Concepción, Ags.    2.00
# 19               Derivadora Pabellón, Ags.    1.70
# 20                  Sierra Fría, Ags. SMN*    0.60
# 21                        Sandovales, Ags.    0.00
# 22                       La Tinaja 2, Ags.    0.00
# 23                      Villa Juárez, Ags.    0.41

# %%
data_2021.keys()
# Out:
# Index(['LON', 'LAT', 'EDO', 'CLAVE', 'ESTACION', 'ene-22'], dtype='object')

# %%
data_2021['ene-21'].hist(bins=50)

# %%
data_2021.plot(kind="scatter", x="LON", y="LAT",alpha=0.1)

# %%
# c is the attribute we'll map onto colors, s is the attribute we'll represent with circle size.
data_2021.plot(kind="scatter", x="LON", y="LAT",c='ene-21', label="ene-21", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)
plt.legend()
plt.show()

# %%
  data_2021_2022=pd.merge(data_2021,data_2022,on=["LON","LAT","EDO","CLAVE","ESTACION"],how="outer")

# %%
data_2021_2022
# Out:
#              LON        LAT  EDO     CLAVE              ESTACION  ene-21  \
# 0    -102.309722  21.895000  AGS     AGSAG  Aguascalientes, Ags.    11.2
# 1    -102.184167  21.738611  AGS     BRTAG     San Bartolo, Ags.     4.3
# 2    -102.712222  21.849167  AGS  CALVILLO   Calvillo, Ags. SMN*     7.4
# 3    -102.676944  21.997500  AGS     CDRAG     La Codorniz, Ags.     3.5
# 4    -102.189167  21.826667  AGS     CLVAG        Calvillo, Ags.    11.6
# ...          ...        ...  ...       ...                   ...     ...
# 1446 -101.985556  22.264722  ZAC     LORZC          Loreto, Zac.     NaN
# 1447 -103.443056  24.287222  ZAC     MGAZC     Miguel Auza, Zac.     NaN
# 1448 -102.615000  24.983056  ZAC     NTAZC   Nuevo Tampico, Zac.     NaN
# 1449 -102.269444  22.577778  ZAC     OCAZC    Ojo Caliente, Zac.     NaN
# 1450 -102.344167  23.288611  ZAC     VCOZC    Villa de Cos, Zac.     NaN
#
#       ene-22
# 0       1.50
# 1       0.00
# 2       1.75
# 3       0.00
# 4       1.70
# ...      ...
# 1446    0.00
# 1447    0.00
# 1448    1.13
# 1449    1.30
# 1450    0.00
#
# [1451 rows x 7 columns]

# %%
# c is the attribute we'll map onto colors, s is the attribute we'll represent with circle size.
for i in range(1,3):
  data_2021_2022.plot(kind="scatter", x="LON", y="LAT",c=f"ene-2{i}", label=f"ene-2{i}", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)
  plt.legend()
  plt.show()

# %%
# %pip install tabula-py
import tabula
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tabula-py
#   Downloading tabula_py-2.5.1-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 18.6 MB/s
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.21.6)
# Collecting distro
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.8.0 tabula-py-2.5.1

# %%
lluvias= tabula.io.read_pdf("https://smn.conagua.gob.mx/tools/DATA/Climatolog%C3%ADa/Pronóstico%20climático/Temperatura%20y%20Lluvia/PREC/2021.pdf", pages='all')
lluvias=lluvias[0]

# %%
lluvias.head()
# Out:
#                Entidad   Ene   Feb   Mar   Abr    May    Jun    Jul    Ago  \
# 0       Aguascalientes   6.2   0.0   0.0   1.9   22.7  124.1  176.6  117.5
# 1      Baja California  26.8   1.3  14.1   1.4    0.0    0.2    3.0    7.5
# 2  Baja California Sur  12.2   0.2   0.1   0.0    0.0    9.4   10.8   53.5
# 3             Campeche  52.8  21.1  30.4  21.6  137.5  196.8  143.6  147.7
# 4             Coahuila   3.5   4.6   0.2  10.9   37.3   34.1   55.7   43.0
#
#      Sep    Oct   Nov   Dic   Anual
# 0  185.5   36.6   0.2   1.1   672.3
# 1    3.8    3.0   0.7  37.3    99.1
# 2   53.7    6.6   3.3  23.7   173.5
# 3  230.4  138.7  52.4  45.8  1218.7
# 4   24.1   12.0  16.2   5.0   246.5

# %%
lluvias.describe()
# Out:
#               Ene        Feb        Mar        Abr         May         Jun  \
# count   33.000000  33.000000  33.000000  33.000000   33.000000   33.000000
# mean    23.515152   8.303030  10.681818  13.518182   65.069697  183.893939
# std     31.670818  13.801936  16.796139  14.163762   57.800824  134.824692
# min      0.200000   0.000000   0.000000   0.000000    0.000000    0.200000
# 25%      3.800000   0.200000   0.200000   1.900000   17.000000  107.300000
# 50%     12.200000   1.300000   2.900000  10.900000   62.000000  137.500000
# 75%     26.800000   8.800000  13.800000  21.600000   99.900000  242.300000
# max    150.000000  55.100000  66.700000  51.900000  230.200000  691.700000
#
#               Jul         Ago         Sep         Oct         Nov        Dic  \
# count   33.000000   33.000000   33.000000   33.000000   33.000000  33.000000
# mean   138.830303  192.372727  180.942424   86.372727   24.978788  16.460606
# std     65.225903  138.981510  111.183219   71.131464   35.817740  20.536978
# min      3.000000    7.500000    3.800000    1.300000    0.200000   0.000000
# 25%    112.400000  117.500000  114.000000   47.000000    1.800000   1.100000
# 50%    135.700000  148.400000  181.400000   69.100000    7.400000   5.400000
# 75%    164.100000  236.900000  235.600000  101.200000   36.500000  24.900000
# max    328.500000  705.100000  467.600000  326.000000  138.000000  84.400000
#
#              Anual
# count    33.000000
# mean    944.881818
# std     519.072581
# min      99.100000
# 25%     615.000000
# 50%     780.300000
# 75%    1252.500000
# max    2280.700000

# %%
lluvias.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7facc55d36d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc5136e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc50ed450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc511ea50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7facc50c9b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc508f690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc5042d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc5003290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7facc50032d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc4fb49d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc4f2b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc4ee1b10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7facc4ea3150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc4eda750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc4e90d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7facc4e54390>]],
#       dtype=object)

# %% [markdown]
# Ejercicio: Mira los tutoriales https://pandas.pydata.org/docs/getting_started/index.html y realiza los ejemplos usando las tablas que tenemos, u otras de elección.
